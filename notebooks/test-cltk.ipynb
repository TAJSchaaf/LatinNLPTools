# %%
import pandas as pd
import numpy as np
from cltk import NLP
import os
import time
import json
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 595, in run_forever
#     self._run_once()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/base_events.py", line 1881, in _run_once
#     handle._run()
#   File "/Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3077, in run_cell
#     result = self._run_cell(
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3132, in _run_cell
#     result = runner(coro)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3336, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3519, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3579, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/64/925c1j5s5wq9gx32gmg8jxjw0000gn/T/ipykernel_91977/3805025159.py", line 3, in <module>
#     from cltk import NLP
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/cltk/__init__.py", line 5, in <module>
#     from .nlp import NLP
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/cltk/nlp.py", line 9, in <module>
#     from cltk.languages.pipelines import (
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/cltk/languages/pipelines.py", line 25, in <module>
#     from cltk.embeddings.processes import (
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/cltk/embeddings/__init__.py", line 3, in <module>
#     from .embeddings import *
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/cltk/embeddings/embeddings.py", line 28, in <module>
#     from gensim import models  # type: ignore
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/gensim/__init__.py", line 11, in <module>
#     from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/gensim/parsing/__init__.py", line 4, in <module>
#     from .preprocessing import (  # noqa:F401
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/gensim/parsing/preprocessing.py", line 26, in <module>
#     from gensim import utils
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/gensim/utils.py", line 35, in <module>
#     import scipy.sparse
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/scipy/sparse/__init__.py", line 295, in <module>
#     from ._csr import *
#   File "/Users/Thea/nlplatin/lib/python3.10/site-packages/scipy/sparse/_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: _ARRAY_API not found
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 from cltk import NLP
#       4 import os
#       5 import time
#
# File ~/nlplatin/lib/python3.10/site-packages/cltk/__init__.py:5
#       1 """Init module for importing the CLTK class."""
#       3 from importlib import metadata
# ----> 5 from .nlp import NLP
#       7 curr_version: str = metadata.version("cltk")
#       8 __version__: str = curr_version
#
# File ~/nlplatin/lib/python3.10/site-packages/cltk/nlp.py:9
#       7 from cltk.core.data_types import Doc, Language, Pipeline, Process
#       8 from cltk.core.exceptions import UnimplementedAlgorithmError
# ----> 9 from cltk.languages.pipelines import (
#      10     AkkadianPipeline,
#      11     ArabicPipeline,
#      12     AramaicPipeline,
#      13     ChinesePipeline,
#      14     CopticPipeline,
#      15     GothicPipeline,
#      16     GreekPipeline,
#      17     HindiPipeline,
#      18     LatinPipeline,
#      19     MiddleEnglishPipeline,
#      20     MiddleFrenchPipeline,
#      21     MiddleHighGermanPipeline,
#      22     OCSPipeline,
#      23     OldEnglishPipeline,
#      24     OldFrenchPipeline,
#      25     OldNorsePipeline,
#      26     PaliPipeline,
#      27     PanjabiPipeline,
#      28     SanskritPipeline,
#      29 )
#      30 from cltk.languages.utils import get_lang
#      32 iso_to_pipeline = {
#      33     "akk": AkkadianPipeline,
#      34     "ang": OldEnglishPipeline,
#    (...)
#      51     "san": SanskritPipeline,
#      52 }
#
# File ~/nlplatin/lib/python3.10/site-packages/cltk/languages/pipelines.py:25
#      13 from cltk.core.data_types import Language, Pipeline, Process
#      14 from cltk.dependency.processes import (
#      15     ChineseStanzaProcess,
#      16     CopticStanzaProcess,
#    (...)
#      23     OldFrenchStanzaProcess,
#      24 )
# ---> 25 from cltk.embeddings.processes import (
#      26     ArabicEmbeddingsProcess,
#      27     AramaicEmbeddingsProcess,
#      28     GothicEmbeddingsProcess,
#      29     GreekEmbeddingsProcess,
#      30     LatinEmbeddingsProcess,
#      31     MiddleEnglishEmbeddingsProcess,
#      32     OldEnglishEmbeddingsProcess,
#      33     PaliEmbeddingsProcess,
#      34     SanskritEmbeddingsProcess,
#      35 )
#      36 from cltk.languages.utils import get_lang
#      37 from cltk.lemmatize.processes import (
#      38     GreekLemmatizationProcess,
#      39     LatinLemmatizationProcess,
#      40     OldEnglishLemmatizationProcess,
#      41     OldFrenchLemmatizationProcess,
#      42 )
#
# File ~/nlplatin/lib/python3.10/site-packages/cltk/embeddings/__init__.py:3
#       1 """Init for ``cltk.embeddings``."""
# ----> 3 from .embeddings import *
#       4 from .processes import *
#
# File ~/nlplatin/lib/python3.10/site-packages/cltk/embeddings/embeddings.py:28
#      25 from zipfile import ZipFile
#      27 import numpy as np
# ---> 28 from gensim import models  # type: ignore
#      30 from cltk.core.cltk_logger import logger
#      31 from cltk.core.exceptions import CLTKException, UnimplementedAlgorithmError
#
# File ~/nlplatin/lib/python3.10/site-packages/gensim/__init__.py:11
#       7 __version__ = '4.3.3'
#       9 import logging
# ---> 11 from gensim import parsing, corpora, matutils, interfaces, models, similarities, utils  # noqa:F401
#      14 logger = logging.getLogger('gensim')
#      15 if not logger.handlers:  # To ensure reload() doesn't add another one
#
# File ~/nlplatin/lib/python3.10/site-packages/gensim/parsing/__init__.py:4
#       1 """This package contains functions to preprocess raw text"""
#       3 from .porter import PorterStemmer  # noqa:F401
# ----> 4 from .preprocessing import (  # noqa:F401
#       5     preprocess_documents,
#       6     preprocess_string,
#       7     read_file,
#       8     read_files,
#       9     remove_stopwords,
#      10     split_alphanum,
#      11     stem_text,
#      12     strip_multiple_whitespaces,
#      13     strip_non_alphanum,
#      14     strip_numeric,
#      15     strip_punctuation,
#      16     strip_short,
#      17     strip_tags,
#      18 )
#
# File ~/nlplatin/lib/python3.10/site-packages/gensim/parsing/preprocessing.py:26
#      23 import string
#      24 import glob
# ---> 26 from gensim import utils
#      27 from gensim.parsing.porter import PorterStemmer
#      30 STOPWORDS = frozenset([
#      31     'all', 'six', 'just', 'less', 'being', 'indeed', 'over', 'move', 'anyway', 'four', 'not', 'own', 'through',
#      32     'using', 'fifty', 'where', 'mill', 'only', 'find', 'before', 'one', 'whose', 'system', 'how', 'somewhere',
#    (...)
#      58     'make', 'once'
#      59 ])
#
# File ~/nlplatin/lib/python3.10/site-packages/gensim/utils.py:35
#      32 import types
#      34 import numpy as np
# ---> 35 import scipy.sparse
#      36 from smart_open import open
#      38 from gensim import __version__ as gensim_version
#
# File ~/nlplatin/lib/python3.10/site-packages/scipy/sparse/__init__.py:295
#     292 import warnings as _warnings
#     294 from ._base import *
# --> 295 from ._csr import *
#     296 from ._csc import *
#     297 from ._lil import *
#
# File ~/nlplatin/lib/python3.10/site-packages/scipy/sparse/_csr.py:11
#       9 from ._matrix import spmatrix
#      10 from ._base import _spbase, sparray
# ---> 11 from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
#      12                            get_csr_submatrix)
#      13 from ._sputils import upcast
#      15 from ._compressed import _cs_matrix
#
# ImportError: numpy.core.multiarray failed to import

# %%
# Load the default Pipeline for Latin
cltk_nlp = NLP(language="lat")
# Removing ``LatinLexiconProcess`` for this demo b/c it is slow (adds ~9 mins total)
cltk_nlp.pipeline.processes.pop(-1)
# print(cltk_nlp.pipeline.processes)
from cltk.lemmatize.lat import LatinLemmatizer
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Load the default Pipeline for Latin
# ----> 2 cltk_nlp = NLP(language="lat")
#       3 # Removing ``LatinLexiconProcess`` for this demo b/c it is slow (adds ~9 mins total)
#       4 cltk_nlp.pipeline.processes.pop(-1)
#
# NameError: name 'NLP' is not defined

# %%
notebook_path = os.path.abspath("03-cltk.ipynb")
SAMPLE_TYPES = ["glosses"]
MODEL_NAME = "CLTK"
# Results storage
results = {
    "model_name": MODEL_NAME,
    "processing_times": {},
    "accuracy": {},
    "precision": {},
    "recall": {},
    "f1_score": {}
}

# %%
# Load gold standard data
gold_df = pd.read_csv(f"../data/gold_standard/gs_{sample_type}.csv")

# Group by sample_id to reconstruct original texts
sample_texts = []
for sample_id in gold_df['sample_id'].unique():
    sample_df = gold_df[gold_df['sample_id'] == sample_id].sort_values('word_id')
    words = sample_df['word'].tolist()
    text = ' '.join(words)
    sample_texts.append((sample_id, text, sample_df))


all_results = []
for sample_id, text, sample_df in sample_texts:
    # Process with CLTK

    cltk_doc = cltk_nlp.analyze(text)

    # get all the tokens in a list
    toks = cltk_doc.tokens

    # get all the tokens in a list
    lems = cltk_doc.lemma

    # get all the pos tags in a list
    pos_tags = cltk_doc.pos
    print(lems)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[38], line 23
#      20 toks = cltk_doc.tokens
#      22 # get all the tokens in a list
# ---> 23 lems = cltk_doc.lemma
#      25 # get all the pos tags in a list
#      26 pos_tags = cltk_doc.pos
#
# AttributeError: 'Doc' object has no attribute 'lemma'

# %%
# open the ittb file that contains only the tokens of the test set
with open("../random-training-data-other-taggers/test_tok_ittb.txt") as ittb:
    # read and strip the lines
    content = ittb.read().strip()
# and analyze the content with cltk
cltk_doc = cltk_nlp.analyze(text=content)

# get all the tokens in a list
toks = cltk_doc.tokens
# get all the pos tags in a list
pos_tags = cltk_doc.pos

# write output token, pos into files
with open("../random-training-data-other-taggers/test_sets/cltk_ittb.txt", "w") as out:
    for ind,token in enumerate(toks):
        # add newline character at end of every line for formatting
        row = token+"\t"+pos_tags[ind]+"\n"
        out.write(row)
